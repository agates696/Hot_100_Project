# %%
import pandas as pd

# %%
df = pd.read_csv("Data/songs_clusters.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         artist                   album  \
# 0           0         MEDUZA                Paradise
# 1           1  Ariana Grande               Positions
# 2           2   Shawn Mendes                  Wonder
# 3           3     The Weeknd    In Your Eyes (Remix)
# 4           4  Fleetwood Mac  Rumours (Super Deluxe)
#
#                              track_name                track_id  danceability  \
# 0       Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr         0.632
# 1                motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT         0.789
# 2                                Wonder  5KCbr5ndeby4y4ggthdiAb         0.333
# 3  In Your Eyes (feat. Kenny G) - Remix  1SySkCqhEG6Z68o2n07Bsr         0.606
# 4                Dreams - 2004 Remaster  0ofHAoxe9vBkTCp2UQIavz         0.828
#
#    energy  key  loudness  mode  speechiness  instrumentalness  liveness  \
# 0   0.595    8    -7.644     0       0.0401          0.000000    0.2090
# ...

# %%
cluster_7 = df.loc[df['cluster'] == 7]

# %%
cluster_7.to_csv("Data/cluster_7.csv")

# %%
cluster_8 = df.loc[df['cluster'] == 8]

# %%
cluster_8.to_csv("Data/cluster_8.csv")

# %%
cluster_6 = df.loc[df['cluster'] == 6]

# %%
cluster_6.to_csv("Data/cluster_6.csv")

# %%
cluster_5 = df.loc[df['cluster'] == 5]

# %%
cluster_5.to_csv("Data/cluster_5.csv")

# %%
cluster_4 = df.loc[df['cluster'] == 4]

# %%
cluster_4.to_csv("Data/cluster_4")

# %%
cluster_3 = df.loc[df['cluster'] == 3]

# %%
cluster_3.to_csv("Data/cluster_3")

# %%
cluster_2 = df.loc[df['cluster'] == 2]

# %%
cluster_2.to_csv("Data/cluster_2")

# %%
cluster_1 = df.loc[df['cluster'] == 1]

# %%
cluster_1.to_csv("Data/cluster_1")

# %%
# Out:
#      Unnamed: 0  Unnamed: 0.1            artist  \
# 0            12            12     Justin Bieber
# 1            90            90     Justin Bieber
# 2            97            97         BLACKPINK
# 3           114           114        Katy Perry
# 4           207           207          SG Lewis
# ..          ...           ...               ...
# 263        4303          4303            Camilo
# 264        4413          4413             Ne-Yo
# 265        4908          4908              Kano
# 266        4936          4936     Alec Benjamin
# 267        5065          5065  Rhiannon Giddens
#
#                                       album  \
# 0                                      Holy
# 1                                      Holy
# 2             Ice Cream (with Selena Gomez)
# 3                                     Smile
# 4                                 Chemicals
# ..                                      ...
# 263                         Por Primera Vez
# ...
