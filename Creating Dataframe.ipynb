# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="aac1ac9a179f4d02b944ef2bd3ec22ee",
    client_secret="6c4b68aad01b4201affc7d7a2d4cbe11"))

# %%
mood_booster = sp.user_playlist_tracks(user="spotify", playlist_id="spotify:user:spotify:playlist:37i9dQZF1DX3rxVfibe1L0")

# %%
mood_booster_uri = "spotify:user:spotify:playlist:37i9dQZF1DX3rxVfibe1L0"

# %%
playlist_creator = "Spotify"
playlist_id = "37i9dQZF1DX3rxVfibe1L0"

# %%
def analyze_playlist(creator, playlist_id):
    playlist_features_list = ["artist","album","track_name","track_id","danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    
    for track in playlist:
        playlist_features = {}
        
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
            
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
    return playlist_df

# %%
playlist_mood_boost = analyze_playlist(playlist_creator, playlist_id)

# %%
playlist_mood_boost.to_csv("Data/mood_boost.csv")

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXdPec7aLTmlC"

# %%
playlist_happy = analyze_playlist(playlist_creator, playlist_id)

# %%
happy_mood = playlist_mood_boost.append(playlist_happy)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWVinJBuv0P4z"

# %%
playlist_feel_good_c = analyze_playlist(playlist_creator, playlist_id)

# %%
feel_happy_mood = happy_mood.append(playlist_feel_good_c)

# %%
playlist_creator = "Spotify"
playlist_id = "37i9dQZF1DWYBO1MoTDhZI"

# %%
playlist_vibes = analyze_playlist(playlist_creator, playlist_id)

# %%
happy_mood_vibes = happy_mood.append(playlist_vibes)

# %%
happy_mood_vibes
# Out:
#            artist                                      album  \
# 0          MEDUZA                                   Paradise
# 1   Ariana Grande                                  Positions
# 2    Shawn Mendes                                     Wonder
# 3      The Weeknd                       In Your Eyes (Remix)
# 4   Fleetwood Mac                     Rumours (Super Deluxe)
# ..            ...                                        ...
# 95      Absofacto                            Thousand Peaces
# 96       88rising                                   Warpaint
# 97       The 1975  A Brief Inquiry Into Online Relationships
# 98         Broods                                      Peach
# 99          Dansu                          Don't You Give Up
#
#                                 track_name                track_id  \
# 0          Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr
# 1                   motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT
# ...

# %%
playlist_creator = "Spotify"
playlist_id = "37i9dQZF1DWUAZoWydCivZ"

playlist_pos_vibes = analyze_playlist(playlist_creator, playlist_id)

happy_pos_mood_vibes = happy_mood_vibes.append(playlist_pos_vibes)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:2k995mbzd5f9ui49qh23xp2tr:playlist:3IBrsav3Sh8AImtaGoaP07"

playlist_morn = analyze_playlist(playlist_creator, playlist_id)

happy_vibes_morning = happy_pos_mood_vibes.append(playlist_morn)

# %%
playlist_creator = "manifesto"
playlist_id = "spotify:user:manifesto.:playlist:6WwLgLnb6dcbd1meHOd5W3"

playlist_hype = analyze_playlist(playlist_creator, playlist_id)

happy_vibes = happy_vibes_morning.append(playlist_hype)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:jennalee1416:playlist:42bWDk5Y3DJTdRkBfZf5W4"

playlist_windows = analyze_playlist(playlist_creator, playlist_id)

happy_driving = happy_vibes.append(playlist_windows)

# %%
playlist_creator = "Taylor Belfort"
playlist_id = "spotify:user:taybelfort:playlist:76WckOlpzIA63Kxspzf2RS"

playlist_guard = analyze_playlist(playlist_creator, playlist_id)

happy_guardians = happy_driving.append(playlist_guard)

# %%
playlist_creator = "spotify:user:1232839603"
playlist_id = "spotify:user:1232839603:playlist:1A9br0tXZki9pVI4kob9sZ"

playlist_me = analyze_playlist(playlist_creator, playlist_id)

happy_songs = happy_guardians.append(playlist_me)

# %%
playlist_creator = "spotify:user:1920bd5cnyteqfiiekl64y997"
playlist_id = "spotify:user:1920bd5cnyteqfiiekl64y997:playlist:36IZg1bdC78r9IawSOxbuB"

playlist_big = analyze_playlist(playlist_creator, playlist_id)

largest = happy_songs.append(playlist_big)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbITWG1ZJKYt"
playlist_jazz = analyze_playlist(playlist_creator, playlist_id)

with_jazz = largest.append(playlist_jazz)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWWEJlAGA9gs0"
playlist_class = analyze_playlist(playlist_creator, playlist_id)

with_class = with_jazz.append(playlist_class)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWSV3Tk4GO2fq"
playlist_50 = analyze_playlist(playlist_creator, playlist_id)

with_50 = with_class.append(playlist_50)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXaKIA8E7WcJj"
playlist_60 = analyze_playlist(playlist_creator, playlist_id)

with_60 = with_50.append(playlist_60)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWTJ7xPn4vNaz"
playlist_70 = analyze_playlist(playlist_creator, playlist_id)

with_70 = with_60.append(playlist_70)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:myplay.com:playlist:19PgP2QSGPcm6Ve8VhbtpG"
playlist_80 = analyze_playlist(playlist_creator, playlist_id)

with_80 = with_70.append(playlist_80)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbTxeAdrVG2l"
playlist_90 = analyze_playlist(playlist_creator, playlist_id)

with_90 = with_80.append(playlist_90)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:ti97t6pc8emg8fzolgr9au1ee:playlist:5tW8T4fK7DoTtLr8ordLpa"
playlist_00 = analyze_playlist(playlist_creator, playlist_id)

with_00 = with_90.append(playlist_00)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX5Ejj0EkURtP"
playlist_10 = analyze_playlist(playlist_creator, playlist_id)

with_10 = with_00.append(playlist_10)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:v1p3rp0n3:playlist:1qZYxKhwvYwzn17B9MAPcR"
playlist_40 = analyze_playlist(playlist_creator, playlist_id)

with_40 = with_10.append(playlist_40)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:1244428002:playlist:7sH38YpA9gyFWU12ganusb"
playlist_30 = analyze_playlist(playlist_creator, playlist_id)

with_30 = with_40.append(playlist_30)

# %%
playlist_creator = "spotify:user:nat_999"
playlist_id = "spotify:user:nat_999:playlist:7olpTqGzGrYuI76ZBlCLgs"
playlist_20 = analyze_playlist(playlist_creator, playlist_id)

with_20 = with_30.append(playlist_20)

# %%
playlist_creator = "spotify:user:nat_999"
playlist_id = "spotify:user:nat_999:playlist:0wHbVF37bPUvdnT4SzNg8l"
playlist_20f = analyze_playlist(playlist_creator, playlist_id)

with_20f = with_20.append(playlist_20f)

# %%
with_20f
# Out:
#             artist                                    album  \
# 0           MEDUZA                                 Paradise
# 1    Ariana Grande                                Positions
# 2     Shawn Mendes                                   Wonder
# 3       The Weeknd                     In Your Eyes (Remix)
# 4    Fleetwood Mac                   Rumours (Super Deluxe)
# ..             ...                                      ...
# 95     India Adams                   Comfort Me with Apples
# 96   Fran Jeffries     Fran Can Really Hang You Up the Most
# 97       Peggy Lee                              I Like Men!
# 98  Lizabeth Scott                                      Men
# 99      Annie Ross  Gypsy (Music From The Broadway Musical)
#
#                               track_name                track_id  \
# 0        Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr
# 1                 motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT
# ...

# %%
with_20f.to_csv("Data/audio_features.csv")

# %%
with_20f
# Out:
#             artist                                    album  \
# 0           MEDUZA                                 Paradise
# 1    Ariana Grande                                Positions
# 2     Shawn Mendes                                   Wonder
# 3       The Weeknd                     In Your Eyes (Remix)
# 4    Fleetwood Mac                   Rumours (Super Deluxe)
# ..             ...                                      ...
# 95     India Adams                   Comfort Me with Apples
# 96   Fran Jeffries     Fran Can Really Hang You Up the Most
# 97       Peggy Lee                              I Like Men!
# 98  Lizabeth Scott                                      Men
# 99      Annie Ross  Gypsy (Music From The Broadway Musical)
#
#                               track_name                track_id  \
# 0        Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr
# 1                 motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT
# ...

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX3qCx5yEZkcJ"
playlist_01 = analyze_playlist(playlist_creator, playlist_id)

with_02 = with_20f.append(playlist_01)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX9sIqqvKsjG8"
playlist_03 = analyze_playlist(playlist_creator, playlist_id)

playlist04 = with_02.append(playlist_03)

# %%
playlist_creator = "ChilledCow"
playlist_id = "spotify:user:chilledcow:playlist:0vvXsWCC9xrXsKd4FyS8kM"
playlist_04 = analyze_playlist(playlist_creator, playlist_id)

playlist_05 = playlist04.append(playlist_04)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbYM3nMM0oPk"
playlist_07 = analyze_playlist(playlist_creator, playlist_id)

playlist_08 = playlist_05.append(playlist_07)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbYM3nMM0oPk"
playlist_09 = analyze_playlist(playlist_creator, playlist_id)

playlist_10 = playlist_08.append(playlist_09)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWTwnEm1IYyoj"
playlist_11 = analyze_playlist(playlist_creator, playlist_id)

playlist_12 = playlist_10.append(playlist_11)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWVA1Gq4XHa6U"
playlist_13 = analyze_playlist(playlist_creator, playlist_id)

playlist_14 = playlist_12.append(playlist_13)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX2SK4ytI2KAZ"
playlist_15 = analyze_playlist(playlist_creator, playlist_id)

playlist_16 = playlist_14.append(playlist_15)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX2rBR3X9E86S"
playlist_17 = analyze_playlist(playlist_creator, playlist_id)

playlist_18 = playlist_16.append(playlist_17)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWWJOmJ7nRx0C"
playlist_19 = analyze_playlist(playlist_creator, playlist_id)

playlist_20 = playlist_18.append(playlist_19)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX8WMG8VPSOJC"
playlist_21 = analyze_playlist(playlist_creator, playlist_id)

playlist_22 = playlist_20.append(playlist_21)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:64FJj5HaUHR6KrKSsU8KPx"
playlist_23 = analyze_playlist(playlist_creator, playlist_id)

playlist_24 = playlist_22.append(playlist_23)

# %%
playlist_24.to_csv("Data/audio_features2.csv")

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX62Nfha2yFhL"
playlist_25 = analyze_playlist(playlist_creator, playlist_id)

playlist_26 = playlist_24.append(playlist_25)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX1tW4VlEfDSS"
playlist_27 = analyze_playlist(playlist_creator, playlist_id)

playlist_28 = playlist_26.append(playlist_27)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX91oIci4su1D"
playlist_29 = analyze_playlist(playlist_creator, playlist_id)

playlist_30 = playlist_28.append(playlist_29)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:0NfjMqrzcGKVsbYZmhf4Md"
playlist_31 = analyze_playlist(playlist_creator, playlist_id)

playlist_32 = playlist_30.append(playlist_31)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWUzFXarNiofw"
playlist_33 = analyze_playlist(playlist_creator, playlist_id)

playlist_34 = playlist_32.append(playlist_33)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX9wa6XirBPv8"
playlist_35 = analyze_playlist(playlist_creator, playlist_id)

playlist_36 = playlist_34.append(playlist_35)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX4EKARgqYPFZ"
playlist_37 = analyze_playlist(playlist_creator, playlist_id)

playlist_38 = playlist_36.append(playlist_37)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:jet1744:playlist:6ZyCKGUenZukJwzSSy3o05"
playlist_39 = analyze_playlist(playlist_creator, playlist_id)

playlist_40 = playlist_38.append(playlist_39)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:jet1744:playlist:6ZyCKGUenZukJwzSSy3o05"
playlist_39 = analyze_playlist(playlist_creator, playlist_id)

playlist_40 = playlist_38.append(playlist_39)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX3LDIBRoaCDQ"
playlist_41 = analyze_playlist(playlist_creator, playlist_id)

playlist_42 = playlist_40.append(playlist_41)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:gorillaz_:playlist:0gcwyY9y7l2uXkXwBVuXtw"
playlist_43 = analyze_playlist(playlist_creator, playlist_id)

playlist_44 = playlist_42.append(playlist_43)

# %%
playlist_44
# Out:
#            artist                    album  \
# 0          MEDUZA                 Paradise
# 1   Ariana Grande                Positions
# 2    Shawn Mendes                   Wonder
# 3      The Weeknd     In Your Eyes (Remix)
# 4   Fleetwood Mac   Rumours (Super Deluxe)
# ..            ...                      ...
# 31       Gorillaz   Song Machine Episode 1
# 32       Gorillaz   Song Machine Episode 1
# 33       Gorillaz   Song Machine Episode 1
# 34       Gorillaz   Song Machine Episode 1
# 35       Gorillaz  Song Machine Theme Tune
#
#                                      track_name                track_id  \
# 0               Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr
# 1                        motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT
# 2                                        Wonder  5KCbr5ndeby4y4ggthdiAb
# 3          In Your Eyes (feat. Kenny G) - Remix  1SySkCqhEG6Z68o2n07Bsr
# 4                        Dreams - 2004 Remaster  0ofHAoxe9vBkTCp2UQIavz
# ...

# %%
playlist_creator = "Maxim Averbukh"
playlist_id = "spotify:user:thedoctorkto:playlist:54nv8jbrm4JoHEZ49Qvjgl"
playlist_45 = analyze_playlist(playlist_creator, playlist_id)

playlist_46 = playlist_44.append(playlist_45)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX10zKzsJ2jva"
playlist_47 = analyze_playlist(playlist_creator, playlist_id)

playlist_48 = playlist_46.append(playlist_47)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX0XUsuxWHRQd"
playlist_49 = analyze_playlist(playlist_creator, playlist_id)

playlist_50 = playlist_48.append(playlist_49)

# %%
playlist_creator = "Urban Outfitters"
playlist_id = "spotify:user:urbanoutfitters:playlist:6dx5oJUjDQO9OdZ5Li2YZh"
playlist_51 = analyze_playlist(playlist_creator, playlist_id)

playlist_52 = playlist_50.append(playlist_51)

# %%
playlist_52.to_csv("Data/audio_features3.csv")

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbEm2sKzgoJ8"
playlist_53 = analyze_playlist(playlist_creator, playlist_id)

playlist_54 = playlist_52.append(playlist_53)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWX3387IZmjNa"
playlist_55 = analyze_playlist(playlist_creator, playlist_id)

playlist_56 = playlist_54.append(playlist_55)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX50QitC6Oqtn"
playlist_57 = analyze_playlist(playlist_creator, playlist_id)

playlist_58 = playlist_56.append(playlist_57)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXbrUpGvoi3TS"
playlist_59 = analyze_playlist(playlist_creator, playlist_id)

playlist_60 = playlist_58.append(playlist_59)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX09mi3a4Zmox"
playlist_61 = analyze_playlist(playlist_creator, playlist_id)

playlist_62 = playlist_60.append(playlist_61)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX4laDTTxplAf"
playlist_63 = analyze_playlist(playlist_creator, playlist_id)

playlist_64 = playlist_62.append(playlist_63)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX7rOY2tZUw1k"
playlist_65 = analyze_playlist(playlist_creator, playlist_id)

playlist_66 = playlist_64.append(playlist_65)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXaUvpePTXR1D"
playlist_67 = analyze_playlist(playlist_creator, playlist_id)

playlist_68 = playlist_66.append(playlist_67)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DX7Z7kYpKKGTc"
playlist_69= analyze_playlist(playlist_creator, playlist_id)

playlist_70 = playlist_68.append(playlist_69)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWVf1Phr4ZVgO"
playlist_71= analyze_playlist(playlist_creator, playlist_id)

playlist_72 = playlist_70.append(playlist_71)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DXe5Q8muTQked"
playlist_73= analyze_playlist(playlist_creator, playlist_id)

playlist_74 = playlist_72.append(playlist_73)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWZqyWCBK6QTt"
playlist_75= analyze_playlist(playlist_creator, playlist_id)

playlist_76 = playlist_74.append(playlist_75)

# %%
playlist_creator = "Spotify"
playlist_id = "spotify:user:spotify:playlist:37i9dQZF1DWXmlLSKkfdAk"
playlist_77= analyze_playlist(playlist_creator, playlist_id)

playlist_78 = playlist_76.append(playlist_77)

# %%
playlist_78
# Out:
#               artist                                    album  \
# 0             MEDUZA                                 Paradise
# 1      Ariana Grande                                Positions
# 2       Shawn Mendes                                   Wonder
# 3         The Weeknd                     In Your Eyes (Remix)
# 4      Fleetwood Mac                   Rumours (Super Deluxe)
# ..               ...                                      ...
# 95  Rhiannon Giddens   Just the Two of Us (feat. Sxip Shirey)
# 96              SOAK  I Can't Make You Love Me/Immigrant Song
# 97    Madilyn Bailey                                Despacito
# 98       The Mayries                 Black Beatles (Acoustic)
# 99             Erato                      Hello (Adele Cover)
#
#                                 track_name                track_id  \
# 0          Paradise (feat. Dermot Kennedy)  6ft4hAq6yde8jPZY2i5zLr
# 1                   motive (with Doja Cat)  5GkQIP5mWPi4KZLLXeuFTT
# ...

# %%
playlist_78.to_csv("Data/audio_features3.csv")
